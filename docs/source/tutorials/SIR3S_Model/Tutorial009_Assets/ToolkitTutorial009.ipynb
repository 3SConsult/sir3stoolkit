# %% [markdown]
# # Tutorial 9: Model Validation

# %%
SIR3S_SIRGRAF_DIR = r"C:\3S\SIR 3S\SirGraf-90-15-00-24_Quebec-Upd2" #change to local path

# %% [markdown]
# ## Imports

# %% [markdown]
# Note: The SIR 3S Toolkit requires the Sir3S_Toolkit.dll included in SIR 3S installations (version Quebec and higher).

# %%
import sir3stoolkit

# %% [markdown]
# The core of sir3stoolkit is a Python wrapper around basic functionality of SIR 3S, offering a low-level access to the creation, modification and simulation of SIR 3S models. In the future pure python subpackages may be added.

# %%
from sir3stoolkit.core import wrapper

# %%
sir3stoolkit
# Out:
# <module 'sir3stoolkit' from 'C:\\Users\\aUsername\\3S\\sir3stoolkit\\src\\sir3stoolkit\\__init__.py'>

# %% [markdown]
# The [wrapper package](https://3sconsult.github.io/sir3stoolkit/references/sir3stoolkit.core.html#sir3stoolkit.core.wrapper.Initialize_Toolkit) has to be initialized with reference to a SIR 3S (SirGraf) installation.

# %%
wrapper.Initialize_Toolkit(SIR3S_SIRGRAF_DIR)
# Out:
# [2026-05-16 20:10:23,334] INFO in sir3stoolkit.core.wrapper: [Initialization] Using provided SirGraf path: C:\3S\SIR 3S\SirGraf-90-15-00-24_Quebec-Upd2
# [2026-05-16 20:10:23,334] INFO in sir3stoolkit.core.wrapper: [Initialization] Using provided SirGraf path: C:\3S\SIR 3S\SirGraf-90-15-00-24_Quebec-Upd2
# [2026-05-16 20:10:23,363] INFO in sir3stoolkit.core.wrapper: [Initialization] Initializing toolkit with SirGraf path: C:\3S\SIR 3S\SirGraf-90-15-00-24_Quebec-Upd2

# %% [markdown]
# ## Initialization

# %% [markdown]
# The SIR 3S Toolkit contains two classes: [SIR3S_Model](https://3sconsult.github.io/sir3stoolkit/references/sir3stoolkit.core.html#sir3stoolkit.core.wrapper.SIR3S_Model) (model and data) and [SIR3S_View](https://3sconsult.github.io/sir3stoolkit/references/sir3stoolkit.core.html#sir3stoolkit.core.wrapper.SIR3S_View) (depiction in SIR Graf). All SIR 3S Toolkit functionality is accessed via the methods of these classes.

# %%
s3s = wrapper.SIR3S_Model()
# Out:
# [2026-05-16 20:10:23,818] INFO in sir3stoolkit.core.wrapper: [Model Class Initialization] Initialization complete

# %%
s3s_view = wrapper.SIR3S_View()
# Out:
# [2026-05-16 20:10:23,874] INFO in sir3stoolkit.core.wrapper: Initialization complete

# %% [markdown]
# ## Open Model

# %%
dbFilePath=r"Toolkit_Tutorial9_Model.db3"

# %%
s3s.OpenModel(dbName=dbFilePath, 
              providerType=s3s.ProviderTypes.SQLite, 
              Mid="M-1-0-1", 
              saveCurrentlyOpenModel=False, 
              namedInstance="", 
              userID="", 
              password="")
# Out:
# [2026-05-16 20:10:28,726] INFO in sir3stoolkit.core.wrapper: Model is open for further operation

# %% [markdown]
# Now the model has been opened and the previous one has been closed without saving it. All SIR 3S Toolkit commands now apply to this model until another one is opened.

# %% [markdown]
# # ExecuteModelValidation()

# %% [markdown]
# We can use the function [ExecuteModelValidation()](https://3sconsult.github.io/sir3stoolkit/references/sir3stoolkit.core.html#sir3stoolkit.core.wrapper.SIR3S_Model.ExecuteModelValidation) to validate the model.

# %%
model_check  = s3s.ExecuteModelValidation()

# %% [markdown]
# We use json to unpack the return.

# %%
import json

# %%
model_check = json.loads(model_check)

# %%
model_check[0]
# Out:
# [{'ElementType': 'ROHR',
#   'Element': '5327930626528922667',
#   'ElementName': 'Rohr K0000 K0001',
#   'MessageCodes': ['25200070'],
#   'Messages': ['Rohrlänge darf nicht kleiner oder gleich 0 sein.'],
#   'Categories': ['Value'],
#   'Weights': ['10'],
#   'Datapoint': '-1',
#   'DatapointName': ''}]

# %% [markdown]
# # ExecuteResultsCheck()

# %% [markdown]
# We can use the function [ExecuteResultsCheck()](https://3sconsult.github.io/sir3stoolkit/references/sir3stoolkit.core.html#sir3stoolkit.core.wrapper.SIR3S_Model.ExecuteResultsCheck) to check calculated results.

# %% [markdown]
# To be able to perform the results check, the model must be calculated first.

# %%
s3s.ExecCalculation(True)
# Out:
# [2026-05-16 20:10:37,984] INFO in sir3stoolkit.core.wrapper: Model Calculation is complete

# %%
result_check, datapoint_check_results = s3s.ExecuteResultsCheck()
# Out:
# [2026-05-16 20:10:38,032] ERROR in sir3stoolkit.core.wrapper: Error: An error occurred during Results Check: Beim aufrufenden Thread muss es sich um einen STA-Thread handeln, da dies für viele Komponenten der Benutzeroberfläche erforderlich ist.

# %% [markdown]
# ## result_check

# %%
datapoint_check_results = json.loads(datapoint_check_results)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 datapoint_check_results = json.loads(datapoint_check_results)
#
# File c:\Users\jablonski\AppData\Local\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\jablonski\AppData\Local\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\jablonski\AppData\Local\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
